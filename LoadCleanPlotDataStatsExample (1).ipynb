# %% [markdown]
# ### Loading and plotting data
#
# Author:
# - |
#     Sofia Dahl, sof@create.aau.dk\
#     Dept. Architecture, Design and Media Technology, Aalborg University Copenhagen
# ---
#
# After working your way through this notebook you should be able to...
# -   Load and plot data from excel file
# -   Mask extreme values as NaN and drop them

# %%
#Loading libraries we will use in this notebook
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
# !{sys.executable} -m pip install scipy
import scipy.stats as stats
import statistics
# Out:
# Requirement already satisfied: scipy in /opt/conda/lib/python3.12/site-packages (1.17.1)
# Requirement already satisfied: numpy<2.7,>=1.26.4 in /opt/conda/lib/python3.12/site-packages (from scipy) (2.4.2)

# %%
#The first column (col 0) does not contain anything useful
#Since we already know this we can skip this and just use columns 1-3
data = pd.read_csv('SUS.csv', sep=';')

# %%
data
# Out:
#     User ID:  Q1  Q2  Q3  Q4  Q5  Q6  Q7  Q9  Q9.1  Q10
# 0          1   2   4   4   4   3   4   4   4     4    4
# 1          2   3   3   3   4   2   3   2   2     3    4
# 2          2   3   2   3   3   3   3   3   3     3    4
# 3          3   2   3   2   3   3   3   3   2     4    3
# 4          4   3   4   4   4   4   4   4   4     3    3
# 5          5   3   3   3   3   3   2   3   3     3    2
# 6          6   3   3   3   3   3   3   4   4     3    4
# 7          7   3   4   3   4   3   3   3   3     4    3
# 8          8   2   3   3   3   3   3   4   2     3    3
# 9          9   2   4   3   4   3   3   4   4     3    4
# 10        10   2   2   2   3   3   2   3   2     2    2
# 11        11   1   4   4   1   1   1   4   1     1    3
# 12        12   3   3   3   4   3   3   4   4     3    4
# 13        13   2   3   3   3   4   3   4   4     3    3
# 14        14   1   3   3   3   2   3   3   3     3    2
# 15        15   1   4   4   4   2   3   4   3     4    3
# 16        16   2   4   4   4   4   4   4   4     4    4

# %%
newData = data.drop(columns=['User ID:'])
print(newData)
# Out:
#     Q1  Q2  Q3  Q4  Q5  Q6  Q7  Q9  Q9.1  Q10
# 0    2   4   4   4   3   4   4   4     4    4
# 1    3   3   3   4   2   3   2   2     3    4
# 2    3   2   3   3   3   3   3   3     3    4
# 3    2   3   2   3   3   3   3   2     4    3
# 4    3   4   4   4   4   4   4   4     3    3
# 5    3   3   3   3   3   2   3   3     3    2
# 6    3   3   3   3   3   3   4   4     3    4
# 7    3   4   3   4   3   3   3   3     4    3
# 8    2   3   3   3   3   3   4   2     3    3
# 9    2   4   3   4   3   3   4   4     3    4
# 10   2   2   2   3   3   2   3   2     2    2
# 11   1   4   4   1   1   1   4   1     1    3
# 12   3   3   3   4   3   3   4   4     3    4
# 13   2   3   3   3   4   3   4   4     3    3
# 14   1   3   3   3   2   3   3   3     3    2
# 15   1   4   4   4   2   3   4   3     4    3
# 16   2   4   4   4   4   4   4   4     4    4

# %%
Sumed=newData.sum(axis=1)

# %%
print(2.5*Sumed)
# Out:
# 0     92.5
# 1     72.5
# 2     75.0
# 3     70.0
# 4     92.5
# 5     70.0
# 6     82.5
# 7     82.5
# 8     72.5
# 9     85.0
# 10    57.5
# 11    52.5
# 12    85.0
# 13    80.0
# 14    65.0
# 15    80.0
# 16    95.0
# dtype: float64
